# %% [markdown]
# # Ensuring Reliable Few-Shot Prompt Selection for LLMs

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cleanlab/cleanlab-tools/blob/master/few_shot_prompt_selection/few_shot_prompt_selection.ipynb)

# %% [markdown]
# In this notebook, we prompt the Davinci LLM from OpenAI (the model underpinning GPT-3/ChatGPT) with few-shot prompts in an effort to classify the intent of customer service requests at a large bank. Following typical practice, we source the few-shot examples to include in the prompt template from an available dataset of human-labeled request examples. However, the resulting LLM predictions are unreliable — a close inspection reveals this is because real-world data is messy and error-prone.  LLM performance in this customer service intent classification task is only marginally boosted by manually modifying the prompt template to mitigate potentially noisy data. The LLM predictions become significantly more accurate if we instead use data-centric AI algorithms via Cleanlab Studio to ensure only high-quality few-shot examples are selected for inclusion in the prompt template.

# %% [markdown]
# # Imports and Helpers

# %%
import pandas as pd
import numpy as np
import warnings
import openai, os
from openai import OpenAI
import string
import random
import tiktoken
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from langchain.prompts import PromptTemplate
from langchain.prompts import FewShotPromptTemplate
warnings.filterwarnings('ignore')
pd.set_option('max_colwidth', None)

def eval_preds(preds):
    acc = accuracy_score(preds, test.label.values)
    return "Model Accuracy: " + '{:.1%}'.format(acc)

def tokens_per_prompt(prompt):
    encoding = tiktoken.get_encoding("p50k_base")
    num_tokens = len(encoding.encode(prompt))
    return num_tokens

def cost_per_prompt(prompt):
    cost_per_token = 0.02 / 1000
    tokens = tokens_per_prompt(prompt)
    cost = tokens * cost_per_token
    return cost

def cost_per_test_evaluation(examples_pool, test):
    texts = test.text.values
    cost = 0
    examples = get_examples(examples_pool)
    for text in texts:
        prompt = get_prompt(examples_pool, text, examples)
        prompt_cost = cost_per_prompt(prompt)
        cost += prompt_cost
    return "${:,.2f}".format(cost)

# %% [markdown]
# # OpenAI API Key
# Replace with your own key.

# %%
client = OpenAI(
    api_key="sk-TZn2hZ39D7YDD8vKw8P28JhK0AYQbE7vI2WtyB80rwi3WcDi",  # 或者 os.environ["OPENAI_API_KEY"]
    base_url="https://sg.uiuiapi.com/v1",  # 注意最好加 /v1,
    # model="gpt-3.5-turbo"
)

# %%
# neg = pd.read_csv(r'/root/reinforcement_commit/datasets/dataset.csv')
from sklearn.model_selection import train_test_split
df = pd.read_csv('./dataset.csv')
# df.dropna(inplace=True)
# label2id = {'Adaptive':0,'Perfective':1,'Corrective':2}
# df = df.replace({"labels": label2id})
# df.rename(columns={'labels':'label','diffs':'diff','msgs':'message'},inplace=True)
# df

train_df, temp_df = train_test_split(df, test_size=0.3, random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# %% [markdown]
# # Building the Few-Shot Prompt
# Few-shot prompting is a technique used in natural language processing that enables pretrained foundation models to perform complex tasks without any explicit training (i.e. updates to model parameters).  In few-shot prompting (also known as in-context learning), we provide a model with a limited number of input-output pairs, as part of a prompt template that is included in the prompt used to instruct the model how to handle a particular input.
#
# Our prompt will consist of a few pieces:
# - (optional) prefix
# - list of class labels to help LLM choose a valid class
# - (optional) 50 examples, one from each class
# - target text for LLM to classify

# %% [markdown]
# ## Adding List of Classes for Valid Completions
#
# This text will go at the beginning of the prompt and will tell the LLM what the valid classes are so that it can consistently output a class. Without this, the LLM will not choose a valid class and output something not parsable.
#
# Here we can also add an optional `prefix` that we will use later.

# %% [markdown]
# ## Generate Entire Prompt

# %%
def num_tokens_from_messages(messages, model="gpt-3.5-turbo-0301"):
    """Returns the number of tokens used by a list of messages."""
    try:
        encoding = tiktoken.encoding_for_model(model)
    except KeyError:
        encoding = tiktoken.get_encoding("cl100k_base")
    if model == "gpt-3.5-turbo-0301":  # note: future models may deviate from this
        num_tokens = 0
        for message in messages:
            num_tokens += (
                4  # every message follows <im_start>{role/name}\n{content}<im_end>\n
            )
            for key, value in message.items():
                num_tokens += len(encoding.encode(value))
                if key == "name":  # if there's a name, the role is omitted
                    num_tokens += -1  # role is always required and always 1 token
        num_tokens += 2  # every reply is primed with <im_start>assistant
        return num_tokens
    else:
        raise NotImplementedError(
            f"""num_tokens_from_messages() is not presently implemented for model {model}.
  See https://github.com/openai/openai-python/blob/main/chatml.md for information on how messages are converted to tokens."""
        )

# %%
val_df.columns
# Out:
# Index(['commit_sha', 'maintenance_type', 'commit_diff', 'commit_message',
#        'CODE_CHANGE_FILE', 'CODE_ADD_CODE_LINE', 'CODE_DEL_CODE_LINE',
#        'CODE_MOD_CODE_LINE', 'CODE_ADD_COMMENT_LINE', 'CODE_DEL_COMMENT_LINE',
#        'CODE_MOD_COMMENT_LINE', 'TEST_CHANGE_FILE', 'TEST_ADD_CODE_LINE',
#        'TEST_DEL_CODE_LINE', 'TEST_MOD_CODE_LINE', 'TEST_ADD_COMMENT_LINE',
#        'TEST_DEL_COMMENT_LINE', 'TEST_MOD_COMMENT_LINE', 'TEST_ADD_OTHER_LINE',
#        'TEST_DEL_OTHER_LINE', 'TEST_MOD_OTHER_LINE', 'BUILD_CHANGE_FILE',
#        'BUILD_ADD_LINE', 'BUILD_DEL_LINE', 'BUILD_MOD_LINE', 'DOC_CHANGE_FILE',
#        'DOC_ADD_LINE', 'DOC_DEL_LINE', 'DOC_MOD_LINE', 'OTHER_CHANGE_FILE',
#        'OTHER_ADD_LINE', 'OTHER_DEL_LINE', 'OTHER_MOD_LINE'],
#       dtype='object')

# %%
# Helper to format the k-shot prompt with:
# - prefix
# - 1 example from each class
# - target text for classification
def generate_promot(row):
    base_promot = """
    Please act as a commit message generator,
    I will provide you with the code diff for a commit,
    and you need to give me the commit message for this commit.
    Please avoid any explanations and only provide the  commit message .
    """

    # commit_message_prompt = f"commit message: {row['msgs']}\n"
    commit_codediff_prompt = f"code diff: {row['commit_diff']}\n"

    prompt = base_promot +  commit_codediff_prompt

    messages = [{"role": "user", "content": prompt}]

    l, r = 0, len(commit_codediff_prompt) - 1
    while l <= r:
        mid = (l + r) // 2
        prompt = base_promot +  commit_codediff_prompt[:mid]
        messages = [{"role": "user", "content": prompt}]

        ok = num_tokens_from_messages(messages) < 4096
        if ok:
            l = mid + 1
        else:
            r = mid - 1
    prompt = base_promot + commit_codediff_prompt[:r]

    return prompt

# %% [markdown]
# ## Query OpenAI LLM API

# %%
# Helper method to prompt OpenAI LLM and get response.
def get_response(user_content):
    response = client.chat.completions.create(
    model="gpt-3.5-turbo",  # 根据代理方文档修改
    messages=[
        {"role": "user", "content": user_content}
    ]
    )
    print(response.choices[0].message.content)
    
    return response.choices[0].message.content

# text = "\'How can I change my pin?\'"
# examples = get_examples(examples_pool)
# df = pd.read_csv('dataset.csv')

result = []
for i, row in val_df.iterrows():
    user_content = generate_promot(row)
    # print(user_content)
    response =  get_response(user_content)
    result.append(response)
    # print("Model classified ", user_content, " as ", response)
# Out:
# Update support for various root stores and add information on how to build on Windows.
# Fixed bug related to starting waiting downloads unintentionally and causing segmentation fault.
# Update dependencies and verification scripts.
# MAPREDUCE-2766. Fixed NM to set secure permissions for files and directories in distributed-cache.
# Refactor PosixPath to Path in test_corrector file
# Revert @noinline once Closure issue is resolved. Add @noinline Disable inlining due to issue with Closure in listeners inside embedded views.
# Add support for custom foreign key suffixes in server routes
# Refactoring MPS operations and adding batch_first support in RNN implementation.
# Refactored MyApplication constructor to handle IOException
# feat: Improve MetricsQueryEditor functionality and UI
# Fix typo in method name: SignallAll() to SignalAll()
# Refactor file name configuration in PyPropertyTestSuite
# fix: Update attribute stringification in get_slot_data.ts and add new Nested component with config and main file
# Fix error in `req.subdomains` on empty host
# Remove duplicate database exposition in router module
# feat: Add setting for concurrent shard rebalancing in AckClusterUpdateSettingsIT
# Serialize non-string types in event `emit` by automatically casting them.
# Add support for response headers in reverse proxy handler.
# Refactor gulpfile.js and create-route-param-metadata.decorator.ts
# Update language flags alignment in README.md
# Change translations for file names in Chinese, Esperanto, and French languages, implement timer for auto-update, and add functionality for deleting files and directories.
# Add CKA_NSS_MOZILLA_CA_POLICY CK_BBOOL CK_TRUE flag for various certificates.
# Add support for embedded documents with OType.EMBEDDED in CSV serialization.
# Bump version to 1.11.5 unstable
# Refactor test cases and coverage handling in tests script
# Added theme accessibility to the Tauri runtime API.
# Refactor model and tokenizer imports and optimizations in README
# Refactoring build configuration and helper functions.
# Update package.json with new versions of dependencies
# Added XStream converters for KBaseImpl, KProjectImpl, and KSessionImpl classes. Updated the KProjectExtension.java file to use KProjectImpl instead of XStream conversion.
# Add karma-sauce-launcher to package.json
# Fix host addition in OStorageRemote and parse server URLs.
# Refactor logic to include all non-js, non-css assets in async file mapping
# Update chunk size for reading files, fix error handling and debug messages, add test for non-existing file.
# Add dynamic_thread_pool to the server files and test suite, and include dynamic_thread_pool.h in the grpc++ library.
# Update margin for markdown container from 16px top and bottom to 8px top and 16px bottom.
# Fix Puppeteer setup for GitlabCI环境 to launch headless Chrome成功.
# Add fields and initialization code for type info, object instance, and class object in the ImplementationBodyCodegen class.
# Refactor linting and testing scripts in package.json
# Refactored animation enablement method names.
# Update version numbers for Bower, npm, and Meteor installs
# Return token_type and fix issue with code refactoring for JSON parser.
# Refactor capabilities and debug functions for file handlers.
# chore: update imports for date and time pickers from @mui/lab to @mui/x-date-pickers and @mui/x-date-pickers-pro
# Refactor ZipDataFormat marshalling and unmarshalling operations
# HBASE-12345: Clean META location and close connection in tests
# Update disabled state styling for buttons, close buttons, pagination links, and form range inputs
# Introduce CachedFilter class to support caching and improve performance
# Update setMutexProfileRate method to setMutexProfileFraction in web3ext
# Fix a typo in the comment and include additional Unicode scripts in header_links.rb; correct a typo in JSX attribute name in jsx-in-depth.ko-KR.md; update a link in reusable-components.ko-KR.md; fix a typo in 06-transferring-props.ja-JP.md; correct a link in 06-transferring-props.zh-CN.md; update a link in forms.ko-KR.md; correct a link in forms.zh-CN.md; and enhance the explanation of refs in more-about-refs.ko-KR.md.
# Add conditional artifact upload for pull requests based on the event type
# Simplified function signatures for pyrDown and pyrUp in GPU module. Fix unnecessary use of borderType parameter.
# Fix typos and inconsistencies in README.md
# Update ContentLength to -1 for CONNECT requests
# Update type definitions for CSS modules to make keys readonly
# Add OutputType::UNKNOWN to enable handling unknown output types in various functions.
# Refactor NextImageContentSourceVc creation in source function
# Refactor toString method parameters and input handling for Buffer and SlowBuffer
# Added sceneEnvironmentChanged signal and environment selection in Sidebar Scene panel.
# Updated CDN links and integrated Leaflet for map display.
# Refactor default visibility setting in KotlinExtractFunctionDialog
# Add support for DynamicSelf in class existentials.
# Refactor get_plans function signature
# Add preset removal functionality and save presets after removal.
# Add pointerEvents:none to Overlay styles
# Add limitations of hosted API and deletion schedule for content.
# Refactored variable name for clarity in get method
# Add event listener for 'hi' on client-side socket.
# Refactor print_entry functions to accept any type implementing the Write trait
# Updated particle initialization. Tracking size after positioning particle. Fixing particle initialization mechanism.
# Remove qDebug statement from setDownloadLocalModelsPath implementation.
# refactor: update class properties to use protected instead of private
# Implemented showPlane for Viz3d.
# Improve maxContentLength check in http adapter
# Refactor DenoDir and CompileDir to use CacheDir instead for better clarity.
# Update OsStr conversion in Utf8CStr impl
# Refactor the benchmark code to use C++ Standard Library functions
# Refactor xnli utility imports.
# Improve extraction of 'thumbnail' field in YahooIE.extract_info
# Add OData extension dependency and refactor DigestTestCase for improved digest handling.
# Updated the code for exporting and importing packages in the Atom module.
# Update Minio image version in docker-compose file
# Update run configuration and debug icons.
# Refactored variable naming logic for literal expressions.
# Update links to examples in README.md and add examples directory with README.md containing information on where to find descriptions.
# Refactor file opening functions for Unix and Windows support
# Fix logic error in checking if attribute is ranked.
# Fix declaration typos and use correct inheritance in field generator classes
# Fix annotation owner interface implementation in JavaElementUtil
# Add RDF schema constants and references to important RDF elements.
# feat: Add support for custom adapter in axios
# Adjusted tests for efficient rendering.
# Added base test for checking binary diff of rules in KnowledgeAgentBinaryDiffTests.
# Refactor SetArgs function parameter to be a pointer for argv array
# Update links and improve extension install instructions in FAQ and guide.
# Update file extensions to .js for web worker script files and fixed typos in README and template files.
# Update README and add multiple screenshots
# Add Korean style guide link
# Refactored model field names in inspectdb test.
# Fix array handling in buildURL function.
# Add support for sorting maps in JSON and XML outputs
# Refactor Strideable protocol and related functions for better readability and consistency
# Refactor ServerStat::toString function to cast last_updated to int64_t
# Update size limit for chart.js and add Colors to import list
# Add Go 1.7 to Travis CI configuration
# Delete file level metadata reflection if map entry message.
# Fix parsing of numeric literals in certain edge cases.
# Release version 1.0, Released on April 26th 2018.
# [core/ext/transport/inproc] Set flag if call failed before receiving message
# [ENHANCEMENT] Kubernetes SD: Allow attaching node metadata to discovered pods. #10080
# Fix video height extraction in Google Drive IE
# Bump terser version to 5.16.0
# Restrict organization creation for regular users based on admin settings and update application version to 0.9.140.0210.
# Fix state initialization in the transaction pool tests.
# Update Scene.html with parameter meta in toJSON method
# Add sync.RWMutex for handling connected state in ProtocolClient
# Add rate limiting to PUT requests in benchmark tool
# Remove unnecessary variables and imports
# Refactor build system to use gox for cross-compilation.
# HADOOP-7001. Configuration changes via Reconfigurable interface.
# Add tests and events for fragment handling in slides.
# Bump @sinonjs/commons to v1.3.1 and @sinonjs/formatio to v3.2.0, update @types/node to v11.9.6, remove outdated dependencies.
# Fixed clear session function to reset TensorFlow default graph properly.
# Add reset chat configuration functionality and UI option to reset to defaults.
# Update Cameron Chapman's employer in README.md
# Fix typo in a comment and ensure correct type conversion in SetClipboardTextFn_DefaultImpl.
# Update Node minimum version to 4 in package.json and createReactApp.js, update version fallback logic in createReactApp.js, minor adjustments to error messages.
# Refactor footer design to improve readability and aesthetics.
# Convert value to ConstraintType in various scenarios
# Update CONTRIBUTING.md with guidelines for providing a simple project for issue reproduction.
# update organization export response format for v2023.1.0
# YARN-2730. DefaultContainerExecutor runs only one localizer at a time
# Add test for EA70945 on smart completion test suite.
# Check for usable bourne shell inside chroot
# Deprecate the `caOptional` option for TLS client authentication.
# Add SVGRenderer to examples/renderers directory, update list.js with new renderer.
# Add Vite guide and examples, update references to Webpack and Parcel
# Update visual.en-US.md to fix typo in "JavaScript" word and correct the link formatting for G2 implementation.
# feat: refactor word derivations and split into functions
# Refactored method to create a WebApplicationContext without throwing exceptions
# Refactor CORS headers in HTTPTransport and XHRPolling.
# Refactor acknowledgements handling in xhr-polling test
# Enable cord handling.
# Fix spelling error in Linear Discriminant Analysis.
# Add infra tracing package to server imports
# Refactor condition of checking output path existence in DeploymentUtilImpl
# Added new Restlet representations for better organization.
# Fix handling of cv value in check_cv function and update test case in test_split.py.
# Refactor object spread syntax to the recent JavaScript specification updates.
# Fixed regression with FK to an object with PK of 0.
# Fix handling of tray and sidecar icons on calling `app.exit()` from JS.
# Set mix_rate and latency values to default constants for consistency across drivers.
# Refactor embedded script context initialization and usage in modules.
# Add deployment script for Travis-CI integration and Docker image building for v1.0.alpha version.
# Refactor ownership check in repo function
# Add aria-label attributes for accessibility in SQLBuilderEditor and MetricStatEditor components
# Add sponsorship for doist to the README and sponsors.yml
# Remove unnecessary code duplication in BeanProcessor.
# Add Subject Key Identifier to CA certificate creation
# Update MockHttpServletResponse with new location header and send redirect functionality.
# Refactor notifier struct and related functions to enable better access and management of notification configurations.
# Add comments for getSlidesMetaInfo function and callRevealApi function in notes plugin.
# Fix FIXME in might_permit_raw_init function
# Register Blueprint CLI commands only if there are any commands available
# Updated copyright year and added exception handling for read-only mode being unsupported.
# Fix security vulnerabilities and update dependencies.
# Fix constructor parameter type in KnowledgeStoreServiceImpl
# Improve handling of warning functions in transform function
# Refactored CDIHelper class and added methods to wire Listeners and Work Item Handlers in KieSession and StatelessKieSession.
# Fix urlencode function parameter default value to use False instead of 0.
# Fix if condition comparison using single quotes instead of double quotes.
# Refactor test functions to remove unnecessary fixture and output parameter duplication
# feat(server): improve revalidation signal for deploy environments and add new test for router revalidation
# Refactor field type monomorphization function to be standalone and receive TyCtxt reference.
# Fix parameter definition in BaseEstimator and MyEstimator classes
# Add Dockerfile for Traefik binary build and run configuration.
# Fix flag detection bug and update file handling modes.
# Refactor session handling, close session after use
# Fix Has and HasAncient method logic bugs
# Fixed partial index creation to address migration issue.
# chore(@nestjs) publish %s release
# feat: add high resolution timer lock for Windows OS
# Update link to Restangular and Json-server prototyping blog post
# Add doOnSubscribe operator to allow action invocation upon subscription
# Add method to retrieve rule names for specific packages and implement related methods
# Refactored HandlerThreadScheduler to use CompositeSubscription and ScheduledIOSAction
# Refactor test classes to use BeforeClass and AfterClass annotations instead of Before and After.
# Bump assert_cmd version to 2.0.2
# Ensure files are created in the current year before running tests, handle date formatting based on current year. Check for files older than a year to avoid test failures.
# Use our fork of go-mssqldb with fixes for unimplemented methods
# Fix YARN-2705: Enhance ResourceManager node-label management, address test failures, and update node-labels store configuration.
# feat(server): add watch mode option for building static standalone preview
# Adjust window minimum size and add router location tracking in ChatLayout, reorganize routes structure, and create ChatGPTPrompts components with configuration and styling.
# Add features and bug fixes to CHANGELOG for version 3.3.11
# Wrap query string in single quotes in `MagiskQuery` constructor and remove new lines from query result in `MagiskQueryBuilder` class.
# Adjust function signature generation to fix prototype arguments for GCC.
# Use capnslog instead of log package for logging in pbutil package
# chore: update dependencies in package.json and yarn.lock files
# Update installation.md to include peer dependencies information.
# Add new Nest devices to DHCP configuration and manifest
# Refactor disconnect and error handling in Transport class
# Refactor issue templates and close unnecessary ones.
# Updated debug context processor to include queries for all database aliases.
# Add support for allowing specific ports for clients.
# i/o: avoid requesting mouse capture if button held and initial click was out of reach for imgui
# Refactor DefaultBetaConstraints indexing logic and increase test coverage for variable constraints.
# Clear diagnostics and reset error and warning count when setting workspace.
# HBASE-1192 LRU-style map for the block cache (Jon Gray and Ryan Rawson via Stack)
# Fix sudo rule to properly handle 'sudo ls' with stderr='Permission denied'
# Added onOpen and onClose event handlers for Date/Time Pickers.
# Refactor function names for clarity and consistency.
# Refactor string to template literal conversion logic improvements
# Update codeowners to include shuding for docs and examples paths
# Remove feature toggle for Azure Monitor Resource Picker and implement changes for resource selection in MetricsQueryEditor.
# Fix socket reuse issue in http server.
# Update CSS styles and button classes for consistency in the app界更新 CSS 样式和按钮类，使应用程序保持一致
# Update editor entry points and configure AMD loader in workerMain file
# Add basic Vim marks feature, create_mark and go_to_mark commands, and update editor modal command handling.
# Update sponsors section and improve financial support information.
# Fix embedding configuration issues in integration tests
# Add handling for RuleDescrBuilder subclasses in ParserHelper
# Improve socket connecting detection and establish new connections intelligently.
# Bump version to 5.0.0-beta.0 in package.json
# Update RouterLink's href handling and normalize absolutely prior to comparison. Fix outlet_spec with getHref helper.
# Fix logic for checking interactive terminal in App.rs
# Refactored argument names in motion estimator initialization
# Updated version to 0.5.2 and last update date to December 10, 2013
# Fix length method in collection class
# Fix implementation status for Plan 9.
# Updated `RuleParser` to include an `auto-focus` option.
# Refactor event handler disposal in Modal class
# Refactored config test cases and added new tests
# Fix comments list to be a dictionary in process_images function
# refactor legacy keyboard mode and key mapping functions in input_service.rs, update key mapping log level in uinput.rs
# Refactor user type comparisons to use enum variants
# lint: detect reserved names/labels for histogram/summary metrics
# Fix issue with encryption key update and secure network creation

# %%
val_df['commit_diff']
# Out:
# 438                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 231                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 251                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 1512    diff --git a/hadoop-mapreduce-project/CHANGES.txt b/hadoop-mapreduce-project/CHANGES.txt\nindex 41be54ab5bf..223ff031ebf 100644\n--- a/hadoop-mapreduce-project/CHANGES.txt\n+++ b/hadoop-mapreduce-project/CHANGES.txt\n@@ -1827,4 +1827,7 @@ Release 0.23.0 - Unreleased\n     TestResourceTrackerService sometimes. (Hitesh Shah via vinodkv)\n \n+    MAPREDUCE-2766. Fixed NM to set secure permissions for files and directories\n+    in distributed-cache. (Hitesh Shah via vinodkv)\n+\n Release 0.22.0 - Unreleased\n \ndiff --git a/hadoop-mapreduce-project/hadoop-yarn/hadoop-yarn-server/hadoop-yarn-server-nodemanager/src/main/java/org/apache/hadoop/yarn/server/nodemanager/containermanager/localizer/FSDownload.java b/hadoop-mapreduce-project/hadoop-yarn/hadoop-yarn-server/hadoop-yarn-server-nodemanager/src/main/java/org/apache/hadoop/yarn/server/nodemanager/containermanager/localizer/FSDownload.java\nindex 671f3ae30b8..85d16907016 100644\n--- a/hadoop-mapreduce-project/hadoop-yarn/hadoop-yarn-server/hadoop-yarn-server-nodemanager/src/main/java/org/apache/hadoop/yarn/server/nodemanager/containermanager/localizer/FSDownload.java\n+++ b/hadoop-mapreduce-project/hadoop-yarn/hadoop-yarn-server/hadoop-yarn-server-nodemanager/src/main/java/org/apache/hadoop/yarn/server/nodemanager/containermanager/localizer/FSDownload.java\n@@ -41,4 +41,5 @@\n import org.apache.hadoop.util.RunJar;\n import org.apache.hadoop.yarn.api.records.LocalResource;\n+import org.apache.hadoop.yarn.api.records.LocalResourceVisibility;\n import org.apache.hadoop.yarn.util.ConverterUtils;\n \n@@ -57,5 +58,11 @@\n   private LocalResource resource;\n   private LocalDirAllocator dirs;\n-  private FsPermission cachePerms = new FsPermission((short) 0755);\n+  private static final FsPermission cachePerms = new FsPermission(\n+      (short) 0755);\n+  static final FsPermission PUBLIC_FILE_PERMS = new FsPermission((short) 0555);\n+  static final FsPermission PRIVATE_FILE_PERMS = new FsPermission(\n+      (short) 0500);\n+  static final FsPermission PUBLIC_DIR_PERMS = new FsPermission((short) 0755);\n+  static final FsPermission PRIVATE_DIR_PERMS = new FsPermission((short) 0700);\n \n   FSDownload(FileContext files, UserGroupInformation ugi, Configuration conf,\n@@ -151,4 +158,5 @@ public Path run() throws Exception {\n       });\n       unpack(new File(dTmp.toUri()), new File(dFinal.toUri()));\n+      changePermissions(dFinal.getFileSystem(conf), dFinal);\n       files.rename(dst_work, dst, Rename.OVERWRITE);\n     } catch (Exception e) {\n@@ -164,9 +172,54 @@ public Path run() throws Exception {\n       resource = null;\n       dirs = null;\n-      cachePerms = null;\n     }\n     return files.makeQualified(new Path(dst, sCopy.getName()));\n   }\n \n+  /**\n+   * Recursively change permissions of all files/dirs on path based \n+   * on resource visibility.\n+   * Change to 755 or 700 for dirs, 555 or 500 for files.\n+   * @param fs FileSystem\n+   * @param path Path to modify perms for\n+   * @throws IOException\n+   * @throws InterruptedException \n+   */\n+  private void changePermissions(FileSystem fs, final Path path)\n+      throws IOException, InterruptedException {\n+    FileStatus fStatus = fs.getFileStatus(path);\n+    FsPermission perm = cachePerms;\n+    // set public perms as 755 or 555 based on dir or file\n+    if (resource.getVisibility() == LocalResourceVisibility.PUBLIC) {\n+      perm = fStatus.isDirectory() ? PUBLIC_DIR_PERMS : PUBLIC_FILE_PERMS;\n+    }\n+    // set private perms as 700 or 500\n+    else {\n+      // PRIVATE:\n+      // APPLICATION:\n+      perm = fStatus.isDirectory() ? PRIVATE_DIR_PERMS : PRIVATE_FILE_PERMS;\n+    }\n+    LOG.debug("Changing permissions for path " + path\n+        + " to perm " + perm);\n+    final FsPermission fPerm = perm;\n+    if (null == userUgi) {\n+      files.setPermission(path, perm);\n+    }\n+    else {\n+      userUgi.doAs(new PrivilegedExceptionAction<Void>() {\n+        public Void run() throws Exception { ...
# 764                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 743                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 949                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 1046                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 341                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 303                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# Name: commit_diff, Length: 237, dtype: object

# %%
val_df['generation_msgs'] = result

# %%
val_df.to_csv('generate_msg.csv',encoding='utf_8_sig')

# %%
# from sklearn.metrics import classification_report, accuracy_score
# print(classification_report(val_df['labels'],result,digits=4))
# Out:
#               precision    recall  f1-score   support
#
#     Adaptive     0.5926    0.5393    0.5647        89
#   Corrective     0.7629    0.8222    0.7914        90
#   Perfective     0.4831    0.4886    0.4859        88
#
#     accuracy                         0.6180       267
#    macro avg     0.6129    0.6167    0.6140       267
# weighted avg     0.6139    0.6180    0.6152       267
